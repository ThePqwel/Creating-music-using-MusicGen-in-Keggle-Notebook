# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/taylor-swift-1989-30s-instrumental-audio-wav/electro_1.json
# /kaggle/input/taylor-swift-1989-30s-instrumental-audio-wav/config.yaml
# /kaggle/input/taylor-swift-1989-30s-instrumental-audio-wav/train.jsonl
# /kaggle/input/taylor-swift-1989-30s-instrumental-audio-wav/electro_2.json
# /kaggle/input/taylor-swift-1989-30s-instrumental-audio-wav/audiocraft_taylor_swift_backup/audiocraft_fix/CONTRIBUTING.md
# /kaggle/input/taylor-swift-1989-30s-instrumental-audio-wav/audiocraft_taylor_swift_backup/audiocraft_fix/LICENSE_weights
# /kaggle/input/taylor-swift-1989-30s-instrumental-audio-wav/audiocraft_taylor_swift_backup/audiocraft_fix/CODE_OF_CONDUCT.md
# /kaggle/input/taylor-swift-1989-30s-instrumental-audio-wav/audiocraft_taylor_swift_backup/audiocraft_fix/mypy.ini
# /kaggle/input/taylor-swift-1989-30s-instrumental-audio-wav/audiocraft_taylor_swift_backup/audiocraft_fix/setup.cfg
# ...

# %%
import os
import subprocess
import requests

WORKING_DIR = "/kaggle/working"
BIN_DIR = os.path.join(WORKING_DIR, "bin")
ENV_PREFIX = os.path.join(WORKING_DIR, "env")
MAMBA_EXE = os.path.join(BIN_DIR, "micromamba")

def run_live(cmd):
    process = subprocess.Popen(cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True)
    for line in process.stdout:
        print(line, end="", flush=True)
    process.wait()
    if process.returncode != 0:
        raise Exception(f"BLAD: {cmd}")

raw_data = """Name                                  Version       Build                  Channel    
──────────────────────────────────────────────────────────────────────────────────────────
  Jinja2                                3.1.6         pypi_0                 pypi       
  Markdown                              3.9           pypi_0                 pypi       
  MarkupSafe                            2.1.5         pypi_0                 pypi       
  PyYAML                                6.0.3         pypi_0                 pypi       
  Pygments                              2.19.2        pypi_0                 pypi       
  Werkzeug                              3.1.5         pypi_0                 pypi       
  _openmp_mutex                         4.5           20_gnu                 conda-forge
  aac-datasets                          0.7.0         pypi_0                 pypi       
  absl-py                               2.3.1         pypi_0                 pypi       
  aiofiles                              23.2.1        pypi_0                 pypi       
  aiohappyeyeballs                      2.6.1         pypi_0                 pypi       
  aiohttp                               3.13.3        pypi_0                 pypi       
  aiosignal                             1.4.0         pypi_0                 pypi       
  annotated-doc                         0.0.4         pypi_0                 pypi       
  annotated-types                       0.7.0         pypi_0                 pypi       
  antlr4-python3-runtime                4.9.3         pypi_0                 pypi       
  anyio                                 4.12.1        pypi_0                 pypi       
  aom                                   3.9.1         hac33072_0             conda-forge
  async-timeout                         5.0.1         pypi_0                 pypi       
  attrs                                 25.4.0        pypi_0                 pypi       
  audiocraft                            1.4.0a2       pypi_0                 pypi       
  audioread                             3.1.0         pypi_0                 pypi       
  av                                    10.0.0        py39h90d6480_4         conda-forge
  blis                                  0.7.11        pypi_0                 pypi       
  brotli                                1.2.0         pypi_0                 pypi       
  bzip2                                 1.0.8         hda65f42_8             conda-forge
  ca-certificates                       2026.1.4      hbd8a1cb_0             conda-forge
  cairo                                 1.18.4        h3394656_0             conda-forge
  catalogue                             2.0.10        pypi_0                 pypi       
  certifi                               2026.1.4      pypi_0                 pypi       
  cffi                                  2.0.0         pypi_0                 pypi       
  charset-normalizer                    3.4.4         pypi_0                 pypi       
  click                                 8.1.8         pypi_0                 pypi       
  cloudpathlib                          0.23.0        pypi_0                 pypi       
  cloudpickle                           3.1.2         pypi_0                 pypi       
  colorlog                              6.10.1        pypi_0                 pypi       
  confection                            0.1.5         pypi_0                 pypi       
  contourpy                             1.3.0         pypi_0                 pypi       
  cycler                                0.12.1        pypi_0                 pypi       
  cymem                                 2.0.13        pypi_0                 pypi       
  datasets                              4.5.0         pypi_0                 pypi       
  dav1d                                 1.2.1         hd590300_0             conda-forge
  decorator                             5.2.1         pypi_0                 pypi       
  demucs                                4.0.1         pypi_0                 pypi       
  dill                                  0.4.0         pypi_0                 pypi       
  docopt                                0.6.2         pypi_0                 pypi       
  dora_search                           0.1.12        pypi_0                 pypi       
  einops                                0.8.2         pypi_0                 pypi       
  encodec                               0.1.1         pypi_0                 pypi       
  exceptiongroup                        1.3.1         pypi_0                 pypi       
  fastapi                               0.128.8       pypi_0                 pypi       
  ffmpeg                                6.1.2         gpl_hdfc89ed_706       conda-forge
  ffmpy                                 1.0.0         pypi_0                 pypi       
  filelock                              3.19.1        pypi_0                 pypi       
  flashy                                0.0.2         pypi_0                 pypi       
  font-ttf-dejavu-sans-mono             2.37          hab24e00_0             conda-forge
  font-ttf-inconsolata                  3.000         h77eed37_0             conda-forge
  font-ttf-source-code-pro              2.038         h77eed37_0             conda-forge
  font-ttf-ubuntu                       0.83          h77eed37_3             conda-forge
  fontconfig                            2.15.0        h7e30c49_1             conda-forge
  fonts-conda-ecosystem                 1             0                      conda-forge
  fonts-conda-forge                     1             hc364b38_1             conda-forge
  fonttools                             4.60.2        pypi_0                 pypi       
  freetype                              2.14.1        ha770c72_0             conda-forge
  fribidi                               1.0.16        hb03c661_0             conda-forge
  frozenlist                            1.8.0         pypi_0                 pypi       
  fsspec                                2025.10.0     pypi_0                 pypi       
  gmp                                   6.3.0         hac33072_2             conda-forge
  gradio                                4.44.1        pypi_0                 pypi       
  gradio_client                         1.3.0         pypi_0                 pypi       
  graphite2                             1.3.14        hecca717_2             conda-forge
  grpcio                                1.78.0        pypi_0                 pypi       
  h11                                   0.16.0        pypi_0                 pypi       
  harfbuzz                              12.2.0        h15599e2_0             conda-forge
  hf-xet                                1.2.0         pypi_0                 pypi       
  httpcore                              1.0.9         pypi_0                 pypi       
  httpx                                 0.28.1        pypi_0                 pypi       
  huggingface_hub                       0.36.2        pypi_0                 pypi       
  hydra-colorlog                        1.2.0         pypi_0                 pypi       
  hydra-core                            1.3.2         pypi_0                 pypi       
  icu                                   75.1          he02047a_0             conda-forge
  idna                                  3.11          pypi_0                 pypi       
  importlib_metadata                    8.7.1         pypi_0                 pypi       
  importlib_resources                   6.5.2         pypi_0                 pypi       
  inflate64                             1.0.4         pypi_0                 pypi       
  joblib                                1.5.3         pypi_0                 pypi       
  julius                                0.2.7         pypi_0                 pypi       
  kiwisolver                            1.4.7         pypi_0                 pypi       
  lame                                  3.100         h166bdaf_1003          conda-forge
  lameenc                               1.8.1         pypi_0                 pypi       
  langcodes                             3.5.1         pypi_0                 pypi       
  lazy_loader                           0.4           pypi_0                 pypi       
  lcms2                                 2.18          h0c24ade_0             conda-forge
  ld_impl_linux-64                      2.45.1        default_hbd61a6d_101   conda-forge
  lerc                                  4.0.0         h0aef613_1             conda-forge
  libabseil                             20240722.0    cxx17_hbbce691_4       conda-forge
  libass                                0.17.3        hba53ac1_1             conda-forge
  libblas                               3.11.0        5_h4a7cf45_openblas    conda-forge
  libcblas                              3.11.0        5_h0358290_openblas    conda-forge
  libdeflate                            1.25          h17f619e_0             conda-forge
  libdrm                                2.4.125       hb03c661_1             conda-forge
  libegl                                1.7.0         ha4b6fd6_2             conda-forge
  libexpat                              2.7.3         hecca717_0             conda-forge
  libffi                                3.5.2         h3435931_0             conda-forge
  libfreetype                           2.14.1        ha770c72_0             conda-forge
  libfreetype6                          2.14.1        h73754d4_0             conda-forge
  libgcc                                15.2.0        he0feb66_17            conda-forge
  libgcc-ng                             15.2.0        h69a702a_17            conda-forge
  libgfortran                           15.2.0        h69a702a_17            conda-forge
  libgfortran5                          15.2.0        h68bc16d_17            conda-forge
  libgl                                 1.7.0         ha4b6fd6_2             conda-forge
  libglib                               2.86.3        h6548e54_1             conda-forge
  libglvnd                              1.7.0         ha4b6fd6_2             conda-forge
  libglx                                1.7.0         ha4b6fd6_2             conda-forge
  libgomp                               15.2.0        he0feb66_17            conda-forge
  libhwloc                              2.12.1        default_h3d81e11_1000  conda-forge
  libiconv                              1.18          h3b78370_2             conda-forge
  libjpeg-turbo                         3.1.2         hb03c661_0             conda-forge
  liblapack                             3.11.0        5_h47877c9_openblas    conda-forge
  liblzma                               5.8.2         hb03c661_0             conda-forge
  liblzma-devel                         5.8.2         hb03c661_0             conda-forge
  libnsl                                2.0.1         hb9d3cd8_1             conda-forge
  libopenblas                           0.3.30        pthreads_h94d23a6_4    conda-forge
  libopenvino                           2024.4.0      hac27bb2_2             conda-forge
  libopenvino-auto-batch-plugin         2024.4.0      h4d9b6c2_2             conda-forge
  libopenvino-auto-plugin               2024.4.0      h4d9b6c2_2             conda-forge
  libopenvino-hetero-plugin             2024.4.0      h3f63f65_2             conda-forge
  libopenvino-intel-cpu-plugin          2024.4.0      hac27bb2_2             conda-forge
  libopenvino-intel-gpu-plugin          2024.4.0      hac27bb2_2             conda-forge
  libopenvino-intel-npu-plugin          2024.4.0      hac27bb2_2             conda-forge
  libopenvino-ir-frontend               2024.4.0      h3f63f65_2             conda-forge
  libopenvino-onnx-frontend             2024.4.0      h5c8f2c3_2             conda-forge
  libopenvino-paddle-frontend           2024.4.0      h5c8f2c3_2             conda-forge
  libopenvino-pytorch-frontend          2024.4.0      h5888daf_2             conda-forge
  libopenvino-tensorflow-frontend       2024.4.0      h6481b9d_2             conda-forge
  libopenvino-tensorflow-lite-frontend  2024.4.0      h5888daf_2             conda-forge
  libopus                               1.6.1         h280c20c_0             conda-forge
  libpciaccess                          0.18          hb9d3cd8_0             conda-forge
  libpng                                1.6.55        h421ea60_0             conda-forge
  libprotobuf                           5.28.2        h5b01275_0             conda-forge
  librosa                               0.11.0        pypi_0                 pypi       
  libsqlite                             3.51.2        h0c1763c_0             conda-forge
  libstdcxx                             15.2.0        h934c35e_17            conda-forge
  libstdcxx-ng                          15.2.0        hdf11a46_17            conda-forge
  libtiff                               4.7.1         h9d88235_1             conda-forge
  libuuid                               2.41.3        h5347b49_0             conda-forge
  libva                                 2.23.0        he1eb515_0             conda-forge
  libvpx                                1.14.1        hac33072_0             conda-forge
  libwebp-base                          1.6.0         hd42ef1d_0             conda-forge
  libxcb                                1.17.0        h8a09558_0             conda-forge
  libxcrypt                             4.4.36        hd590300_1             conda-forge
  libxml2                               2.13.9        h04c0eec_0             conda-forge
  libzlib                               1.3.1         hb9d3cd8_2             conda-forge
  lightning-utilities                   0.15.2        pypi_0                 pypi       
  llvmlite                              0.43.0        pypi_0                 pypi       
  markdown-it-py                        3.0.0         pypi_0                 pypi       
  matplotlib                            3.9.4         pypi_0                 pypi       
  mdurl                                 0.1.2         pypi_0                 pypi       
  mpmath                                1.3.0         pypi_0                 pypi       
  msgpack                               1.1.2         pypi_0                 pypi       
  multidict                             6.7.1         pypi_0                 pypi       
  multiprocess                          0.70.18       pypi_0                 pypi       
  multivolumefile                       0.2.3         pypi_0                 pypi       
  murmurhash                            1.0.15        pypi_0                 pypi       
  ncurses                               6.5           h2d0b736_3             conda-forge
  networkx                              3.2.1         pypi_0                 pypi       
  num2words                             0.5.14        pypi_0                 pypi       
  numba                                 0.60.0        pypi_0                 pypi       
  numpy                                 1.26.4        py39h474f0d3_0         conda-forge
  nvidia-cublas-cu12                    12.1.3.1      pypi_0                 pypi       
  nvidia-cuda-cupti-cu12                12.1.105      pypi_0                 pypi       
  nvidia-cuda-nvrtc-cu12                12.1.105      pypi_0                 pypi       
  nvidia-cuda-runtime-cu12              12.1.105      pypi_0                 pypi       
  nvidia-cudnn-cu12                     8.9.2.26      pypi_0                 pypi       
  nvidia-cufft-cu12                     11.0.2.54     pypi_0                 pypi       
  nvidia-curand-cu12                    10.3.2.106    pypi_0                 pypi       
  nvidia-cusolver-cu12                  11.4.5.107    pypi_0                 pypi       
  nvidia-cusparse-cu12                  12.1.0.106    pypi_0                 pypi       
  nvidia-nccl-cu12                      2.18.1        pypi_0                 pypi       
  nvidia-nvjitlink-cu12                 12.9.86       pypi_0                 pypi       
  nvidia-nvtx-cu12                      12.1.105      pypi_0                 pypi       
  ocl-icd                               2.3.3         hb9d3cd8_0             conda-forge
  omegaconf                             2.3.0         pypi_0                 pypi       
  opencl-headers                        2025.06.13    h5888daf_0             conda-forge
  openh264                              2.4.1         h59595ed_0             conda-forge
  openjpeg                              2.5.4         h55fea9a_0             conda-forge
  openssl                               3.6.1         h35e630c_1             conda-forge
  openunmix                             1.3.0         pypi_0                 pypi       
  orjson                                3.11.5        pypi_0                 pypi       
  packaging                             26.0          pypi_0                 pypi       
  pandas                                2.3.3         pypi_0                 pypi       
  pcre2                                 10.47         haa7fec5_0             conda-forge
  pesq                                  0.0.4         pypi_0                 pypi       
  pillow                                11.3.0        py39h15c0740_0         conda-forge
  pip                                   25.2          pyh8b19718_0           conda-forge
  pixman                                0.46.4        h54a6638_1             conda-forge
  platformdirs                          4.4.0         pypi_0                 pypi       
  pooch                                 1.9.0         pypi_0                 pypi       
  preshed                               3.0.12        pypi_0                 pypi       
  propcache                             0.4.1         pypi_0                 pypi       
  protobuf                              6.33.5        pypi_0                 pypi       
  psutil                                7.2.2         pypi_0                 pypi       
  pthread-stubs                         0.4           hb9d3cd8_1002          conda-forge
  pugixml                               1.14          h59595ed_0             conda-forge
  py7zr                                 1.0.0         pypi_0                 pypi       
  pyarrow                               21.0.0        pypi_0                 pypi       
  pybcj                                 1.0.6         pypi_0                 pypi       
  pycparser                             2.23          pypi_0                 pypi       
  pycryptodomex                         3.23.0        pypi_0                 pypi       
  pydantic                              2.12.5        pypi_0                 pypi       
  pydantic_core                         2.41.5        pypi_0                 pypi       
  pydub                                 0.25.1        pypi_0                 pypi       
  pyparsing                             3.3.2         pypi_0                 pypi       
  pyppmd                                1.2.0         pypi_0                 pypi       
  pystoi                                0.4.1         pypi_0                 pypi       
  python                                3.9.23        hc30ae73_0_cpython     conda-forge
  python-dateutil                       2.9.0.post0   pypi_0                 pypi       
  python-multipart                      0.0.20        pypi_0                 pypi       
  python_abi                            3.9           8_cp39                 conda-forge
  pythonwrench                          0.4.10        pypi_0                 pypi       
  pytz                                  2025.2        pypi_0                 pypi       
  pyzstd                                0.18.0        pypi_0                 pypi       
  readline                              8.3           h853b02a_0             conda-forge
  regex                                 2026.1.15     pypi_0                 pypi       
  requests                              2.32.5        pypi_0                 pypi       
  retrying                              1.4.2         pypi_0                 pypi       
  rich                                  14.3.2        pypi_0                 pypi       
  ruff                                  0.15.1        pypi_0                 pypi       
  safetensors                           0.7.0         pypi_0                 pypi       
  scikit-learn                          1.6.1         pypi_0                 pypi       
  scipy                                 1.13.1        pypi_0                 pypi       
  semantic-version                      2.10.0        pypi_0                 pypi       
  sentencepiece                         0.2.1         pypi_0                 pypi       
  setuptools                            80.9.0        pyhff2d567_0           conda-forge
  shellingham                           1.5.4         pypi_0                 pypi       
  six                                   1.17.0        pypi_0                 pypi       
  smart_open                            7.5.0         pypi_0                 pypi       
  snappy                                1.2.2         h03e3b7b_1             conda-forge
  soundfile                             0.13.1        pypi_0                 pypi       
  soxr                                  1.0.0         pypi_0                 pypi       
  spacy                                 3.7.6         pypi_0                 pypi       
  spacy-legacy                          3.0.12        pypi_0                 pypi       
  spacy-loggers                         1.0.5         pypi_0                 pypi       
  srsly                                 2.5.2         pypi_0                 pypi       
  starlette                             0.49.3        pypi_0                 pypi       
  submitit                              1.5.4         pypi_0                 pypi       
  svt-av1                               2.3.0         h5888daf_0             conda-forge
  sympy                                 1.14.0        pypi_0                 pypi       
  tbb                                   2022.3.0      h8d10470_1             conda-forge
  tensorboard                           2.20.0        pypi_0                 pypi       
  tensorboard-data-server               0.7.2         pypi_0                 pypi       
  texttable                             1.7.0         pypi_0                 pypi       
  thinc                                 8.2.5         pypi_0                 pypi       
  threadpoolctl                         3.6.0         pypi_0                 pypi       
  tk                                    8.6.13        noxft_h366c992_103     conda-forge
  tokenizers                            0.13.3        pypi_0                 pypi       
  tomlkit                               0.12.0        pypi_0                 pypi       
  torch                                 2.1.0         pypi_0                 pypi       
  torchaudio                            2.1.0         pypi_0                 pypi       
  torchdata                             0.7.0         pypi_0                 pypi       
  torchdiffeq                           0.2.5         pypi_0                 pypi       
  torchmetrics                          1.8.2         pypi_0                 pypi       
  torchtext                             0.16.0        pypi_0                 pypi       
  torchvision                           0.16.0+cu118  pypi_0                 pypi       
  torchwrench                           0.7.7         pypi_0                 pypi       
  tqdm                                  4.67.3        pypi_0                 pypi       
  transformers                          4.31.0        pypi_0                 pypi       
  treetable                             0.2.6         pypi_0                 pypi       
  triton                                2.1.0         pypi_0                 pypi       
  typer                                 0.23.1        pypi_0                 pypi       
  typer-slim                            0.23.1        pypi_0                 pypi       
  typing-inspection                     0.4.2         pypi_0                 pypi       
  typing_extensions                     4.15.0        pypi_0                 pypi       
  tzdata                                2025c         hc9c84f9_1             conda-forge
  urllib3                               2.6.3         pypi_0                 pypi       
  uvicorn                               0.39.0        pypi_0                 pypi       
  wasabi                                1.1.3         pypi_0                 pypi       
  wayland                               1.24.0        hd6090a7_1             conda-forge
  wayland-protocols                     1.47          hd8ed1ab_0             conda-forge
  weasel                                0.4.3         pypi_0                 pypi       
  websockets                            12.0          pypi_0                 pypi       
  wheel                                 0.45.1        pyhd8ed1ab_1           conda-forge
  wrapt                                 2.1.1         pypi_0                 pypi       
  x264                                  1!164.3095    h166bdaf_2             conda-forge
  x265                                  3.5           h924138e_3             conda-forge
  xformers                              0.0.22.post7  pypi_0                 pypi       
  xorg-libice                           1.1.2         hb9d3cd8_0             conda-forge
  xorg-libsm                            1.2.6         he73a12e_0             conda-forge
  xorg-libx11                           1.8.13        he1eb515_0             conda-forge
  xorg-libxau                           1.0.12        hb03c661_1             conda-forge
  xorg-libxdmcp                         1.1.5         hb03c661_1             conda-forge
  xorg-libxext                          1.3.7         hb03c661_0             conda-forge
  xorg-libxfixes                        6.0.2         hb03c661_0             conda-forge
  xorg-libxrender                       0.9.12        hb9d3cd8_0             conda-forge
  xxhash                                3.6.0         pypi_0                 pypi       
  xz                                    5.8.2         ha02ee65_0             conda-forge
  xz-gpl-tools                          5.8.2         ha02ee65_0             conda-forge
  xz-tools                              5.8.2         hb03c661_0             conda-forge
  yarl                                  1.22.0        pypi_0                 pypi       
  zipp                                  3.23.0        pypi_0                 pypi       
  zstd                                  1.5.7         hb78ec9c_6             conda-forge"""

conda_pkgs = []
pip_pkgs = []
git_pkgs = [
    "git+https://github.com/facebookresearch/audiocraft.git",
    "git+https://github.com/facebookresearch/demucs.git",
    "git+https://github.com/facebookresearch/encodec.git",
    "git+https://github.com/facebookresearch/flashy.git",
    "git+https://github.com/facebookresearch/dora.git"
]
exclude_from_pip = ["audiocraft", "demucs", "encodec", "flashy", "dora_search"]

for line in raw_data.strip().split('\n'):
    parts = line.split()
    if len(parts) >= 4:
        name = parts[0]
        version = parts[1]
        channel = parts[-1]
        
        if name in exclude_from_pip:
            continue
            
        if channel == 'pypi':
            if name in ['torch', 'torchaudio', 'torchvision']:
                if '+cu' not in version:
                    version = f"{version}+cu118"
            pip_pkgs.append(f"{name}=={version}")
        elif channel == 'conda-forge':
            conda_pkgs.append(f"{name}={version}")

os.makedirs(BIN_DIR, exist_ok=True)
os.chdir(WORKING_DIR)

if not os.path.exists(MAMBA_EXE):
    url = "https://micro.mamba.pm/api/micromamba/linux-64/latest"
    r = requests.get(url, stream=True)
    with open(f"{MAMBA_EXE}.tar.bz2", "wb") as f:
        for chunk in r.iter_content(chunk_size=8192): f.write(chunk)
    run_live(f"tar -xj -C {BIN_DIR} --strip-components=1 -f {MAMBA_EXE}.tar.bz2 bin/micromamba")
    os.chmod(MAMBA_EXE, 0o755)

conda_env_path = os.path.join(WORKING_DIR, "exact_conda_env.yml")
with open(conda_env_path, "w") as f:
    f.write("name: env\nchannels:\n  - conda-forge\ndependencies:\n")
    for pkg in conda_pkgs:
        f.write(f"  - {pkg}\n")

if not os.path.exists(ENV_PREFIX):
    run_live(f"{MAMBA_EXE} env create -y -p {ENV_PREFIX} -f {conda_env_path}")
else:
    run_live(f"{MAMBA_EXE} env update -y -p {ENV_PREFIX} -f {conda_env_path}")

req_path = os.path.join(WORKING_DIR, "exact_requirements.txt")
with open(req_path, "w") as f:
    f.write("--extra-index-url https://download.pytorch.org/whl/cu118\n")
    for pkg in pip_pkgs:
        f.write(f"{pkg}\n")

run_live(f"{MAMBA_EXE} run -p {ENV_PREFIX} pip install -r {req_path}")

for git_pkg in git_pkgs:
    run_live(f"{MAMBA_EXE} run -p {ENV_PREFIX} pip install --no-deps {git_pkg}")

run_live(f"{MAMBA_EXE} install -y -p {ENV_PREFIX} -c conda-forge libsndfile")
run_live(f"{MAMBA_EXE} run -p {ENV_PREFIX} pip install soundfile spacy==3.7.6")
run_live(f"{MAMBA_EXE} run -p {ENV_PREFIX} python -m spacy download en_core_web_sm")

p = "/kaggle/working/env/lib/python3.9/site-packages/submitit/core/plugins.py"
if os.path.exists(p):
    with open(p, "r") as f:
        c = f.read()
    
    o = 'return metadata.entry_points()["submitit"]'
    n = 'return metadata.entry_points().get("submitit", [])'
    
    if o in c:
        c = c.replace(o, n)
        with open(p, "w") as f:
            f.write(c)

os.environ["LD_PRELOAD"] = f"{ENV_PREFIX}/lib/libstdc++.so.6"
os.environ["PYTHONPATH"] = "/kaggle/working/audiocraft_fix"
os.environ["MPLBACKEND"] = "Agg"

print("\n")
verify_cmd = f"{MAMBA_EXE} run -p {ENV_PREFIX} python -c 'import torch; import soundfile; import spacy; import av; print(\"Wszystko pobralo sie poprawnie.\")'"
run_live(verify_cmd)
# Out:
# Transaction
#
#   Prefix: /kaggle/working/env
#
#   Updating specs:
#
#    - _openmp_mutex=4.5
#    - aom=3.9.1
#    - av=10.0.0
#    - bzip2=1.0.8
#    - ca-certificates=2026.1.4
#    - cairo=1.18.4
#    - dav1d=1.2.1
#    - ffmpeg=6.1.2
#    - font-ttf-dejavu-sans-mono=2.37
#    - font-ttf-inconsolata=3.0
#    - font-ttf-source-code-pro=2.38
#    - font-ttf-ubuntu=0.83
#    - fontconfig=2.15.0
#    - fonts-conda-ecosystem=1
#    - fonts-conda-forge=1
#    - freetype=2.14.1
#    - fribidi=1.0.16
#    - gmp=6.3.0
#    - graphite2=1.3.14
#    - harfbuzz=12.2.0
#    - icu=75.1
#    - lame=3.100
#    - lcms2=2.18
#    - ld_impl_linux-64=2.45.1
#    - lerc=4.0.0
#    - libabseil=20240722.0
#    - libass=0.17.3
#    - libblas=3.11.0
#    - libcblas=3.11.0
#    - libdeflate=1.25
#    - libdrm=2.4.125
#    - libegl=1.7.0
#    - libexpat=2.7.3
#    - libffi=3.5.2
#    - libfreetype=2.14.1
#    - libfreetype6=2.14.1
#    - libgcc=15.2.0
#    - libgcc-ng=15.2.0
#    - libgfortran=15.2.0
# ...

# %%
import os
import shutil
import json

INPUT_BASE = "/kaggle/input/taylor-swift-1989-30s-instrumental-audio-wav"
BACKUP_PATH = os.path.join(INPUT_BASE, "AudioCraft_Taylor_Swift_Fixed")
WORKING_DIR = "/kaggle/working"
WAV_FOLDER = os.path.join(INPUT_BASE, "taylor1989")

if os.path.exists(os.path.join(BACKUP_PATH, "audiocraft_fix")):
    shutil.copytree(os.path.join(BACKUP_PATH, "audiocraft_fix"), 
                    os.path.join(WORKING_DIR, "audiocraft_fix"), dirs_exist_ok=True)

if os.path.exists(os.path.join(BACKUP_PATH, "data")):
    shutil.copytree(os.path.join(BACKUP_PATH, "data"), 
                    os.path.join(WORKING_DIR, "data"), dirs_exist_ok=True)

song_mappings = [
    (0, 6, "Synth-pop instrumental, upbeat song, 117 BPM, G major, high energy, very danceable, 4 beats per bar, Welcome to new york style"),
    (7, 13, "Synth-pop instrumental, neutral song, 96 BPM, F major, high energy, very danceable, 4 beats per bar, Blank Space style"),
    (14, 19, "Synth-pop instrumental, neutral song, 160 BPM, C major, high energy, very danceable, 4 beats per bar, I know places style"),
    (20, 27, "Synth-pop instrumental, melancholic song, 144 BPM, E major, average energy, somewhat danceable, 4 beats per bar, this love style"),
    (28, 35, "Synth-pop instrumental, neutral song, 120 BPM, F major, high energy, very danceable, 4 beats per bar, how you get the girl style"),
    (36, 42, "Synth-pop instrumental, neutral song, 140 BPM, G#/Ab major, high energy, somewhat danceable, 4 beats per bar, wildest dreams style"),
    (43, 48, "Synth-pop instrumental, somber song, 170 BPM, G major, high energy, very danceable, 4 beats per bar, bad blood style"),
    (49, 55, "Synth-pop instrumental, exuberant song, 160 BPM, G major, high energy, very danceable, 4 beats per bar, shake it off style"),
    (56, 61, "Synth-pop instrumental, neutral song, 97 BPM, F major, high energy, very danceable, 4 beats per bar, all you had to do was stay style"),
    (62, 68, "Synth-pop instrumental, somber song, 92 BPM, G major, high energy, somewhat danceable, 4 beats per bar, out of the woods style"),
    (69, 75, "Synth-pop instrumental, neutral song, 95 BPM, D major, high energy, somewhat danceable, 4 beats per bar, style song style"),
    (76, 82, "Synth-pop instrumental, neutral song, 122 BPM, F major, high energy, very danceable, 4 beats per bar, new romantics style"),
    (83, 90, "Synth-pop instrumental, somber song, 170 BPM, D major, average energy, somewhat danceable, 4 beats per bar, you are in love style"),
    (91, 98, "Synth-pop instrumental, melancholic song, 184 BPM, D#/Eb major, high energy, somewhat danceable, 4 beats per bar, wonderland style"),
    (99, 107, "Synth-pop instrumental, somber song, 104 BPM, E major, low energy, very danceable, 4 beats per bar, clean style")
]

MOJE_OPISY = {}
for start, end, desc in song_mappings:
    for i in range(start, end + 1):
        filename = f"1989_inst_{i:04d}.wav"
        MOJE_OPISY[filename] = desc

data_files = ["train.jsonl", "valid.jsonl", "evaluate.jsonl", "generate.jsonl", "data.jsonl"]
for filename in data_files:
    file_path = os.path.join(WORKING_DIR, "data", filename)
    if os.path.exists(file_path):
        new_lines = []
        with open(file_path, 'r') as f:
            for line in f:
                item = json.loads(line)
                old_path = item['path']
                file_name = os.path.basename(old_path)
                item['path'] = os.path.join(WAV_FOLDER, file_name)
                
                if file_name in MOJE_OPISY:
                    item['description'] = MOJE_OPISY[file_name]
                    
                new_lines.append(json.dumps(item))
        
        with open(file_path, 'w') as f:
            f.write("\n".join(new_lines))

# %%
import os
import subprocess
import glob
import yaml

with open("/kaggle/working/audiocraft_fix/config/config.yaml", "r") as f:
    cfg = yaml.safe_load(f)

if 'checkpoint' not in cfg:
    cfg['checkpoint'] = {}
cfg['checkpoint']['keep_every_states'] = []
cfg['checkpoint']['save_last'] = True
cfg['checkpoint']['keep_last'] = 10

with open("/kaggle/working/audiocraft_fix/config/config.yaml", "w") as f:
    yaml.dump(cfg, f)

ENV_PREFIX = "/kaggle/working/env"
MAMBA_EXE = "/kaggle/working/bin/micromamba"
REPO_DIR = "/kaggle/working/audiocraft_fix"

UPDATES_PER_EPOCH = 200
EPOCHS = 10
VALID_SAMPLES = 25
BATCH_SIZE = 4

env_vars = os.environ.copy()
env_vars["LD_PRELOAD"] = f"{ENV_PREFIX}/lib/libstdc++.so.6"
env_vars["PYTHONPATH"] = REPO_DIR
env_vars["MPLBACKEND"] = "Agg"
env_vars["USER"] = "root"

os.chdir(REPO_DIR)

xps_dir = "/tmp/audiocraft_root/xps"
latest_checkpoint = ""
if os.path.exists(xps_dir):
    checkpoints = glob.glob(f"{xps_dir}/*/checkpoint.th")
    if checkpoints:
        latest_checkpoint = max(checkpoints, key=os.path.getmtime)

overrides = f"optim.updates_per_epoch={UPDATES_PER_EPOCH} optim.epochs={EPOCHS} dataset.valid.num_samples={VALID_SAMPLES} dataset.batch_size={BATCH_SIZE} optim.lr=0.001"

if latest_checkpoint:
    overrides += f" continue_from={latest_checkpoint}"

train_cmd = f"{MAMBA_EXE} run -p {ENV_PREFIX} torchrun --nproc_per_node=2 -m audiocraft.train {overrides}"

process = subprocess.Popen(train_cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, env=env_vars)
for line in process.stdout:
    print(line, end="", flush=True)
process.wait()
# Out:
# [2026-02-13 20:48:02,329] torch.distributed.run: [WARNING]
# [2026-02-13 20:48:02,329] torch.distributed.run: [WARNING] *****************************************
# [2026-02-13 20:48:02,329] torch.distributed.run: [WARNING] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# [2026-02-13 20:48:02,329] torch.distributed.run: [WARNING] *****************************************
# Dora directory: /tmp/audiocraft_root
# Dora directory: /tmp/audiocraft_root
# /kaggle/working/env/lib/python3.9/site-packages/hydra/_internal/hydra.py:119: UserWarning: Future Hydra versions will no longer change working directory at job runtime by default.
# See https://hydra.cc/docs/1.2/upgrades/1.1_to_1.2/changes_to_job_working_dir/ for more information.
#   ret = run_job(
# ...

# %%
import os
import subprocess

WORKING_DIR = "/kaggle/working"
ENV_PREFIX = os.path.join(WORKING_DIR, "env")
MAMBA_EXE = os.path.join(WORKING_DIR, "bin", "micromamba")
REPO_DIR = os.path.join(WORKING_DIR, "audiocraft_fix")

# tu zmienic na ID
MODEL_XP_PATH = "/tmp/audiocraft_root/xps/300242d3"

inference_logic = f"""
import os
import sys
import torch
import numpy as np
import torchaudio
from audiocraft.models import MusicGen

model = MusicGen.get_pretrained('facebook/musicgen-small')

checkpoint_path = os.path.join('{MODEL_XP_PATH}', 'checkpoint.th')
if os.path.exists(checkpoint_path):
    state = torch.load(checkpoint_path, map_location='cuda')
    # DODANO strict=False - bez tego wywali błąd!
    model.lm.load_state_dict(state['model'], strict=False)
    print('Zaladowano wagi Taylor Swift: ' + checkpoint_path)
else:
    print('Nie znaleziono checkpointu, Generuje na wagach bazowych.')

model.set_generation_params(duration=15)

# TUTAJ WPISZ SWÓJ PROMPT
descriptions = ['Synth-pop instrumental, 96 BPM, F major, high energy, Blank Space style']

with torch.no_grad():
    outputs = model.generate(descriptions, progress=True)

for idx, one_wav in enumerate(outputs):
    output_path = f'/kaggle/working/wynik_taylor_{{idx}}.wav'
    torchaudio.save(output_path, one_wav.cpu(), 32000)
    print(f'Plik zapisany tutaj: {{output_path}}')
"""

with open("/kaggle/working/inference_final.py", "w") as f:
    f.write(inference_logic)

env_vars = os.environ.copy()
env_vars["MPLBACKEND"] = "Agg"
lib_path = f"{ENV_PREFIX}/lib/libstdc++.so.6"
if os.path.exists(lib_path): env_vars["LD_PRELOAD"] = lib_path
env_vars["LD_LIBRARY_PATH"] = f"{ENV_PREFIX}/lib:" + env_vars.get("LD_LIBRARY_PATH", "")
env_vars["PYTHONPATH"] = REPO_DIR

os.chdir(WORKING_DIR)
run_cmd = f"{MAMBA_EXE} run -p {ENV_PREFIX} python /kaggle/working/inference_final.py"

process = subprocess.Popen(run_cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, env=env_vars)
for line in process.stdout:
    print(line, end="", flush=True)
process.wait()

# Wyświetlenie odtwarzacza po zakończeniu
from IPython.display import Audio, display
if os.path.exists("/kaggle/working/wynik_taylor_0.wav"):
    display(Audio("/kaggle/working/wynik_taylor_0.wav"))
# Out:
# /kaggle/working/env/lib/python3.9/site-packages/torch/nn/utils/weight_norm.py:30: UserWarning: torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.
#   warnings.warn("torch.nn.utils.weight_norm is deprecated in favor of torch.nn.utils.parametrizations.weight_norm.")
# ✅ Zaladowano wagi Taylor Swift: /tmp/audiocraft_root/xps/300242d3/checkpoint.th
#      1 /    753
#      2 /    753
#      3 /    753
#      4 /    753
#      5 /    753
#      6 /    753
#      7 /    753
#      8 /    753
#      9 /    753
#     10 /    753
#     11 /    753
#     12 /    753
#     13 /    753
#     14 /    753
#     15 /    753
#     16 /    753
#     17 /    753
#     18 /    753
#     19 /    753
#     20 /    753
#     21 /    753
#     22 /    753
#     23 /    753
#     24 /    753
#     25 /    753
#     26 /    753
#     27 /    753
#     28 /    753
#     29 /    753
#     30 /    753
#     31 /    753
#     32 /    753
#     33 /    753
# ...

# %%
# !!! tutaj to do zeby zmienic learning rate bo narazie jest w chuj niski

import os
import shutil
import subprocess

tmp_xps = "/tmp/audiocraft_root/xps"
safe_xps = "/kaggle/working/xps_backup"

if not os.path.exists(tmp_xps) and os.path.exists(safe_xps):
    shutil.copytree(safe_xps, tmp_xps)

ENV_PREFIX = "/kaggle/working/env"
MAMBA_EXE = "/kaggle/working/bin/micromamba"
REPO_DIR = "/kaggle/working/audiocraft_fix"

UPDATES_PER_EPOCH = 200
EPOCHS = 30
BATCH_SIZE = 4 

env_vars = os.environ.copy()
env_vars["LD_PRELOAD"] = f"{ENV_PREFIX}/lib/libstdc++.so.6"
env_vars["PYTHONPATH"] = REPO_DIR
env_vars["MPLBACKEND"] = "Agg"
env_vars["USER"] = "root"

os.chdir(REPO_DIR)

overrides = (
    f"optim.updates_per_epoch={UPDATES_PER_EPOCH} "
    f"optim.epochs={EPOCHS} "
    f"dataset.batch_size={BATCH_SIZE} "
    f"optim.lr=0.001 "
    f"schedule.lr_scheduler=cosine "
    f"schedule.cosine.lr_min_ratio=1.0 "
    f"+schedule.cosine.warmup=0 "
    f"checkpoint.save_every=5"
)

train_cmd = f"{MAMBA_EXE} run -p {ENV_PREFIX} torchrun --nproc_per_node=2 -m audiocraft.train {overrides}"

try:
    process = subprocess.Popen(train_cmd, shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, env=env_vars)
    for line in process.stdout:
        print(line, end="", flush=True)
    process.wait()
finally:
    if os.path.exists(tmp_xps):
        os.makedirs(safe_xps, exist_ok=True)
        shutil.copytree(tmp_xps, safe_xps, dirs_exist_ok=True)
# Out:
# [2026-02-13 22:52:16,800] torch.distributed.run: [WARNING]
# [2026-02-13 22:52:16,800] torch.distributed.run: [WARNING] *****************************************
# [2026-02-13 22:52:16,800] torch.distributed.run: [WARNING] Setting OMP_NUM_THREADS environment variable for each process to be 1 in default, to avoid your system being overloaded, please further tune the variable for optimal performance in your application as needed.
# [2026-02-13 22:52:16,800] torch.distributed.run: [WARNING] *****************************************
# Dora directory: /tmp/audiocraft_root
# Dora directory: /tmp/audiocraft_root
# Traceback (most recent call last):
#   File "/kaggle/working/env/lib/python3.9/runpy.py", line 197, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/kaggle/working/env/lib/python3.9/runpy.py", line 87, in _run_code
#     exec(code, run_globals)
#   File "/kaggle/working/audiocraft_fix/audiocraft/train.py", line 163, in <module>
#     main()
# ...
